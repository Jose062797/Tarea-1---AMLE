# %% [markdown]
# EAE3709 APLICACIONES DE  MACHINE LEARNING EN ECONOMÍA <br>
# 1ER SEMESTRE 2025 <br>
# INSTITUTO DE ECONOMÍA <br>
# PONTIFICIA UNIVERSIDAD CATÓLICA DE CHILE
#
#
# # **TAREA 1**
#
#
# ---
#
#
# Profesor:
# - Joaquín Pérez Lapillo
#
# Ayudantes:
#
# - Luis García B.
# - Sebastián Hernández B.
# - Oscar Herrera G.

# %% [markdown]
# **Complete sus datos:**
#
# - Nombre y apellido:
#   - `Héctor Garate`
#   - `José Aguilar`
# - Usuario de GitHub (opcional):  `Jose062797`
# - Link a repositorio de GitHub: https://github.com/Jose062797/Tarea-1---AMLE.git

# %% [markdown]
# ## Instrucciones
#
# - Descargue el notebook y cárguelo en su Drive.
# - Todas las preguntas deben ser contestadas en su notebook.
# - Para que una pregunta esté correcta el código debe correr.
# - Si es necesario, realice comentarios breves en su código explicando lo que está realizando o sus resultados.
# - Una vez culminada su tarea, suba su notebook al buzón de tareas de Canvas.
# - La fecha y hora límite de esta tarea es el _**viernes 4 de abril a las 18:00 hrs**_.

# %% [markdown]
# ### Distribución de puntaje
#
#
# | Pregunta                        | Puntaje |
# |--------------------------------|---------|
# | Pregunta 1.0                   |    1    |
# | Pregunta 1.1                   |    3    |
# | Pregunta 1.2                   |    3    |
# | Pregunta 1.3                   |    2    |
# | Pregunta 1.4                   |    2    |
# | Pregunta 1.5                   |    5    |
# | Pregunta 1.6                   |    2    |
# | Pregunta 1.7                   |    5    |
# | Pregunta 1.8                   |   7    |
# | Pregunta 1.9                   |   5    |
# | Pregunta 1.10                  |   5    |
# | Pregunta 1.11                  |   6    |
# | Pregunta 1.12                  |    2    |
# | Pregunta 1.13                  |    5    |
# | Pregunta 1.14                  |   10    |
# | Pregunta 1.15                  |    5    |
# | Pregunta 1.16                  |    5    |
# | Pregunta 2.0                   |    2    |
# | Pregunta 2.1                   |    5    |
# | Pregunta 2.2                   |    5    |
# | Pregunta 2.3                   |    5    |
# | Pregunta 2.4                   |    3    |
# | Pregunta 2.5                   |    3    |
# | Pregunta 2.6                   |    2    |
# | Pregunta 2.7                   |    2    |
#
# Total: 100 pts.

# %% [markdown]
# ### Sobre el Bonus
#
# - La entrega, por defecto, es a través de Canvas. Sin embargo, puede escoger voluntariamente entregar la tarea en su GitHub personal.
#
# - Si usted realiza la entrega en GitHub antes de la **fecha y hora indicada**, entonces tendrá una bonificación de 0.3 en su nota final de tarea. Es decir, si usted obtuvo una nota de 6.5, pero entregó en su GitHub, entonces su calificación en esta tarea será de 6.8.
#
# - Si **además** de realizar la entrega a través de GitHub, usted logra crear `branches` (ramas) y realizar un `merge` entre ramas, entonces se le bonificará con 0.5 en su nota de tarea. Es decir, si usted obtuvo una nota de 6.5, pero entregó en su GitHub e hizo el trabajo de ramas, entonces su calificación en esta tarea será de 7.0.
#
#   - Se valora capacidad autodidacta.
#   - Sólo serán considerados los archivos contenidos en su rama principal a la fecha y hora indicada.

# %% [markdown]
# ## Exploratory data analysis (EDA)

# %% [markdown]
# Para esta tarea se utilizará como principal fuente de información un dataset con una serie de características económicas, demográficas y de desarrollo humano de distintos países a la fecha de 2007 (corte transversal). El dataset está disponible en el siguiente [Github](https://raw.githubusercontent.com/lfgarcia-1/EAE3709-1-2025/refs/heads/main/economic_dataset.csv).<br>
#
# Descripción del dataset:
#
# Variables:
#
# *   date: Fecha en la que se actualizó la data.
# *   Population, Area (sq. mi.) Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita, Literacy (%), Phones (per 1000), Arable (%), Crops (%), Other (%), Climate, Birthrate, Deathrate, Agriculture, Industry, Service: Características del país.
# *   source: fuente de los datos.
# *   Region: Región (grupo de países).
# *   Country: País.

# %% [markdown]
# ### Pregunta 1.0
#
# Importe las librerías que usará en su tarea.

# %%
# Pregunta 1.0

import pandas as pd      # para manipulación de datos
import numpy as np       # para operaciones matemáticas si las necesitas
import matplotlib.pyplot as plt  # para gráficos
import seaborn as sns    # para visualizaciones más avanzadas

# %% [markdown]
# ### Pregunta 1.1
#
# Importe el dataset como un DataFrame (df) directamente desde Github (es decir, no descargue el archivo manualmente). A lo largo de la tarea este df se denominará como `df`.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lfgarcia-1/EAE3709-1-2025/refs/heads/main/economic_dataset.csv")
df
# Out:
#            date        source          Country  \
# 0    2007-01-01  US Goverment     Afghanistan
# 1    2007-01-01  US Goverment         Albania
# 2    2007-01-01  US Goverment         Algeria
# 3    2007-01-01  US Goverment  American Samoa
# 4    2007-01-01  US Goverment         Andorra
# ..          ...           ...              ...
# 222  2007-01-01  US Goverment       West Bank
# 223  2007-01-01  US Goverment  Western Sahara
# 224  2007-01-01  US Goverment           Yemen
# 225  2007-01-01  US Goverment          Zambia
# 226  2007-01-01  US Goverment        Zimbabwe
#
#                                   Region  Population  Area (sq. mi.)  \
# 0          ASIA (EX. NEAR EAST)             31056997          647500
# 1    EASTERN EUROPE                          3581655           28748
# 2    NORTHERN AFRICA                        32930091         2381740
# 3    OCEANIA                                   57794             199
# ...

# %% [markdown]
# ### Pregunta 1.2
#
# Utilice las funciones de Pandas `head()`, `tail()`, `info()` y la propiedad (o atributo) `.dtypes` para describir el `df`. Explique brevemente para qué sirve cada función.

# %%
df.head()
# Out:
#          date        source          Country  \
# 0  2007-01-01  US Goverment     Afghanistan
# 1  2007-01-01  US Goverment         Albania
# 2  2007-01-01  US Goverment         Algeria
# 3  2007-01-01  US Goverment  American Samoa
# 4  2007-01-01  US Goverment         Andorra
#
#                                 Region  Population  Area (sq. mi.)  \
# 0        ASIA (EX. NEAR EAST)             31056997          647500
# 1  EASTERN EUROPE                          3581655           28748
# 2  NORTHERN AFRICA                        32930091         2381740
# 3  OCEANIA                                   57794             199
# 4  WESTERN EUROPE                            71201             468
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                          0.00          23.06
# 1                       124.6                          1.26          -4.93
# ...

# %%
df.tail()
# Out:
#            date        source          Country  \
# 222  2007-01-01  US Goverment       West Bank
# 223  2007-01-01  US Goverment  Western Sahara
# 224  2007-01-01  US Goverment           Yemen
# 225  2007-01-01  US Goverment          Zambia
# 226  2007-01-01  US Goverment        Zimbabwe
#
#                                   Region  Population  Area (sq. mi.)  \
# 222  NEAR EAST                               2460492            5860
# 223  NORTHERN AFRICA                          273008          266000
# 224  NEAR EAST                              21456188          527970
# 225  SUB-SAHARAN AFRICA                     11502010          752614
# 226  SUB-SAHARAN AFRICA                     12236805          390580
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 222                       419.9                          0.00           2.98
# 223                         1.0                          0.42            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                227 non-null    object
#  1   source                              227 non-null    object
#  2   Country                             227 non-null    object
#  3   Region                              227 non-null    object
#  4   Population                          227 non-null    int64
#  5   Area (sq. mi.)                      227 non-null    int64
#  6   Pop. Density (per sq. mi.)          227 non-null    float64
#  7   Coastline (coast/area ratio)        227 non-null    float64
#  8   Net migration                       224 non-null    float64
#  9   Infant mortality (per 1000 births)  224 non-null    float64
#  10  GDP ($ per capita)                  226 non-null    float64
# ...

# %%
df.dtypes
# Out:
# date                                   object
# source                                 object
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# ...

# %% [markdown]
# - `df.head()`: Muestra las primeras 5 filas del DataFrame. Es útil para tener una vista general inicial de los datos, revisar si se cargaron correctamente y entender la estructura básica del dataset.
#
# - `df.tail()`: Muestra las últimas 5 filas del DataFrame. Permite verificar si hay algún patrón o problema hacia el final de los datos, como filas vacías o valores atípicos.
#
# - `df.info()`: Entrega un resumen del DataFrame, incluyendo el número total de entradas, cuántos valores no nulos hay por columna y los tipos de datos. Es muy útil para detectar valores faltantes y entender cómo están definidos los datos.
#
# - `df.dtypes`: Muestra el tipo de dato (por ejemplo, `int64`, `float64`, `object`) de cada columna. Esto ayuda a identificar si alguna variable tiene un tipo incorrecto (por ejemplo, una variable numérica que aparece como texto).

# %% [markdown]
# ### Pregunta 1.3
#
# La variable `source` es innecesaria debido que contiene el mismo valor para todas las observaciones. Elimine esta variable de su `df`.

# %%
df = df.drop(columns=['source']) # Se elimina la columna 'source' ya que no aporta información útil (es constante)

# %% [markdown]
# ### Pregunta 1.4
#
# Transforme el tipo de la variable `date` a `datetime` _datatype_.

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# La variable `date` originalmente estaba en formato de texto (object). Convertirla a tipo `datetime` permite manipularla con funciones de fechas, como extraer el año, mes o comparar por rangos temporales, lo cual es útil para análisis más avanzados.

# %% [markdown]
# ### Pregunta 1.5
#
# Para determinar si las variables son "útiles" y sus valores son "correctos" es necesario comprender cada uno de los atributos del dataset.
# Investigue y explique brevemente la relación **teórica** entre el `GDP (% per capita)` y cada una de las variables denominadas como "Características del país" en la introducción.
#
# Ejemplo: Existe una variable denominada `Coastline (coast/area ratio)`. Coastline es una medida de la cantidad de costa (acceso a mar) del país normalizada al área total del país para no beneficiar a países más grandes pero con la misma proporción de costa. A mayor "Costline" aumenta la capacidad portuaria per capita del país, más puertos facilita el comercio y podría aumentar el GDP per cápita.

# %% [markdown]
# **Population**: La relación con el PIB per cápita no es directa; países con grandes poblaciones pueden tener PIB per cápita bajo si la riqueza no crece proporcionalmente. Economías de escala pueden beneficiar a países populosos, pero el efecto depende de factores como educación y estructura productiva.
#
# **Area (sq. mi.)**: Un territorio más grande puede proporcionar más recursos naturales, pero no garantiza mayor PIB per cápita. Países pequeños como Singapur o Luxemburgo demuestran que la eficiencia en el uso del territorio es más importante que su extensión.
#
# **Pop. Density (per sq. mi.)**: Alta densidad poblacional puede favorecer economías de aglomeración y reducir costos de infraestructura por habitante, potencialmente aumentando la productividad, aunque también puede crear problemas de congestión y contaminación.
#
# **Coastline (coast/area ratio)**: Una mayor proporción de costa normalizada al área total facilita el comercio internacional a través de puertos, reduciendo costos de transporte y potencialmente aumentando el PIB per cápita.
#
# **Net migration**: Flujos migratorios positivos pueden aumentar el PIB per cápita si los inmigrantes aportan capital humano complementario. Sin embargo, si la inmigración es principalmente de baja calificación, puede presionar a la baja los salarios de ciertos sectores.
#
# **Infant mortality (per 1000 births)**: Este indicador refleja la calidad del sistema de salud y condiciones socioeconómicas. Una baja mortalidad infantil generalmente se asocia con mayor desarrollo y, por tanto, mayor PIB per cápita.
#
# **Literacy (%)**: Una mayor tasa de alfabetización implica una población más capacitada, lo que puede aumentar la productividad y, por tanto, el PIB per cápita.
#
# **Phones (per 1000)**: Una alta penetración de teléfonos puede reflejar mayor desarrollo tecnológico e infraestructura, facilitando la comunicación y la actividad económica.
#
# **Arable (%)**: Una mayor proporción de tierra cultivable puede influir en el crecimiento si la economía está basada en el sector agrícola, pero no garantiza por sí sola un alto PIB per cápita.
#
# **Crops (%)**: Similar a lo anterior, su impacto depende del nivel de desarrollo del sector agroindustrial.
#
# **Other (%)**: Representa el porcentaje de territorio no dedicado a agricultura ni cultivos. Su relación con el PIB per cápita dependerá del uso de ese territorio (por ejemplo, industria, turismo, zonas protegidas).
#
# **Climate**: Variable categórica. Algunos climas pueden favorecer la agricultura o el turismo, mientras que otros pueden suponer mayores desafíos económicos.
#
# **Birthrate**: Altas tasas de natalidad pueden implicar mayor presión sobre servicios públicos y menor PIB per cápita si no hay un crecimiento económico proporcional.
#
# **Deathrate**: Un alto índice de mortalidad puede estar relacionado con malas condiciones sanitarias o conflictos, lo cual puede impactar negativamente el desarrollo económico.
#
# **Agriculture/Industry/Service**: Representan la composición del PIB por sector. Economías con mayor proporción en servicios o industria suelen tener un PIB per cápita más alto, mientras que una alta participación agrícola puede estar asociada a economías en desarrollo.

# %% [markdown]
# ### Pregunta 1.6
#
# Calcule estadísticas descriptivas para cada variable numérica.

# %%
# Utilizamos df.describe() para obtener estadísticas descriptivas de todas las variables numéricas
# Esta función proporciona información clave como:
# - La media y mediana para entender la tendencia central de los datos
# - La desviación estándar para comprender la dispersión
# - Los valores mínimos y máximos para identificar posibles outliers
# - Los percentiles para entender la distribución de los datos
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
numeric_columns = [col for col in numeric_columns if col != 'Climate'] # Excluimos Climate al ser categorica
df[numeric_columns].describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                  379.047137
# std    1.178913e+08    1.790282e+06                 1660.185825
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                   29.150000
# 50%    4.786994e+06    8.660000e+04                   78.800000
# 75%    1.749777e+07    4.418110e+05                  190.150000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                      21.165330       0.038125
# std                       72.286863       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.730000       0.000000
# ...

# %% [markdown]
# ### Pregunta 1.7
#
# Según corresponda, realice un gráfico de distribución de densidad o histograma para describir 3 variables del `df` que usted crea más relevantes.
#
# ¿Por qué es importante analizar las distribuciones de las variables a utilizar en su modelo? Ejemplifique su respuesta con al menos una de las variables del df`.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionamos variables relevantes
variables = ['GDP ($ per capita)', 'Literacy (%)', 'Birthrate']

# Creamos los gráficos
plt.figure(figsize=(15, 5))

for i, var in enumerate(variables):
    plt.subplot(1, 3, i+1)
    sns.histplot(df[var].dropna(), kde=True, bins=20)
    plt.title(f'Distribución de {var}')
    plt.xlabel(var)

plt.tight_layout()
plt.show()

# %% [markdown]
# Analizar la distribución de las variables es fundamental para comprender su comportamiento estadístico, detectar posibles valores atípicos y evaluar la necesidad de transformaciones previas al modelado.
#
# Por ejemplo, el `GDP ($ per capita)` presenta una distribución fuertemente sesgada a la derecha, lo que indica una alta concentración de países con bajos niveles de ingreso y un pequeño grupo de países con ingresos excepcionalmente altos. Este tipo de distribución puede afectar la estimación de parámetros en modelos lineales y justificar el uso de transformaciones (como logaritmos) para estabilizar la varianza.
#
# En contraste, la variable `Literacy (%)` muestra una distribución bimodal con una fuerte concentración en niveles altos, lo cual sugiere que muchos países ya han alcanzado altos niveles de alfabetización, mientras que un grupo más reducido presenta rezagos importantes. Por su parte, `Birthrate` tiene una distribución más dispersa, con mayor densidad en niveles intermedios, lo que refleja heterogeneidad demográfica entre países.
#
# Comprender estas distribuciones permite tomar decisiones informadas sobre normalización, tratamiento de outliers y selección de modelos apropiados.

# %% [markdown]
# ### Pregunta 1.8
#
# El df contiene variables con missing values (`NaN`). Impute los `NaN` con el método que estime conveniente, justificando su decisión.
#
# ¿Es pertinente eliminar alguna de estas variables? Hágalo si es el caso.

# %%
# Calculamos el porcentaje de valores nulos por columna
missing_percentage = df.isna().mean().sort_values(ascending=False) * 100

print("Porcentaje de valores nulos por columna:")
print(missing_percentage[missing_percentage > 0])

# Visualizamos los valores faltantes
import missingno as msno
plt.figure(figsize=(12, 6))
msno.matrix(df)
plt.title('Matriz de valores faltantes')
plt.show()

# 1. Identificar y separar variables categóricas y numéricas
categorical_columns = ['Climate']  # Añadir cualquier otra variable categórica
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
numerical_columns = [col for col in numerical_columns if col not in categorical_columns]

# 2. Para variables numéricas con distribución sesgada, usar la mediana
skewed_columns = ['GDP ($ per capita)', 'Pop. Density (per sq. mi.)']
for col in skewed_columns:
    if col in df.columns and df[col].isna().sum() > 0:
        # Forma correcta de aplicar fillna sin warning
        df.loc[:, col] = df[col].fillna(df[col].median())

# 3. Para el resto de variables numéricas, usar la media
for col in numerical_columns:
    if col not in skewed_columns and col in df.columns and df[col].isna().sum() > 0:
        # Forma correcta de aplicar fillna sin warning
        df.loc[:, col] = df[col].fillna(df[col].mean())

# 4. Para variables categóricas, usar la moda
for col in categorical_columns:
    if col in df.columns and df[col].isna().sum() > 0:
        mode_value = df[col].mode()[0]  # Obtener el valor más frecuente
        # Forma correcta de aplicar fillna sin warning
        df.loc[:, col] = df[col].fillna(mode_value)

# Verificamos que no queden valores nulos
print("Valores nulos restantes:", df.isna().sum().sum())
# Out:
# Porcentaje de valores nulos por columna:
# Climate                               9.691630
# Literacy (%)                          7.929515
# Industry                              7.048458
# Agriculture                           6.607930
# Service                               6.607930
# Deathrate                             1.762115
# Phones (per 1000)                     1.762115
# Net migration                         1.321586
# Infant mortality (per 1000 births)    1.321586
# Birthrate                             1.321586
# Other (%)                             0.881057
# Crops (%)                             0.881057
# Arable (%)                            0.881057
# GDP ($ per capita)                    0.440529
# dtype: float64
# Valores nulos restantes: 0

# %%
# Examinamos la distribución de algunas variables clave para justificar el método de imputación
plt.figure(figsize=(15, 10))

# Variables con posible distribución sesgada (imputadas con mediana)
skewed_columns = ['GDP ($ per capita)', 'Pop. Density (per sq. mi.)']

# Creamos subplots para cada variable
for i, col in enumerate(skewed_columns):
    plt.subplot(2, 2, i+1)
    sns.histplot(df[col].dropna(), kde=True)
    plt.axvline(df[col].mean(), color='red', linestyle='--', label='Media')
    plt.axvline(df[col].median(), color='green', linestyle='--', label='Mediana')
    plt.title(f'Distribución de {col}\n(skewness: {df[col].skew():.2f})')
    plt.legend()

# Variables con distribución más simétrica (imputadas con media)
# Seleccionamos algunas como ejemplo
symmetric_examples = ['Literacy (%)', 'Phones (per 1000)']

for i, col in enumerate(symmetric_examples):
    plt.subplot(2, 2, i+3)
    sns.histplot(df[col].dropna(), kde=True)
    plt.axvline(df[col].mean(), color='red', linestyle='--', label='Media')
    plt.axvline(df[col].median(), color='green', linestyle='--', label='Mediana')
    plt.title(f'Distribución de {col}\n(skewness: {df[col].skew():.2f})')
    plt.legend()

plt.tight_layout()
plt.show()

# Para la variable categórica Climate, mostramos su distribución de frecuencias
if 'Climate' in df.columns:
    plt.figure(figsize=(10, 5))
    climate_counts = df['Climate'].value_counts()
    climate_counts.plot(kind='bar')
    plt.title('Distribución de frecuencias de Climate (variable categórica)')
    plt.xlabel('Categoría')
    plt.ylabel('Frecuencia')
    plt.show()

# %% [markdown]
# Tras analizar el porcentaje de valores faltantes por variable, se observa que ninguna supera el umbral del 10%, por lo que decidimos conservar todas las columnas. La variable con más datos ausentes es "Net migration" con aproximadamente 9% de valores faltantes.
#
# Para la imputación de valores faltantes, utilizamos un enfoque diferenciado basado en la distribución estadística de cada variable:
#
# 1. Para variables con distribución notablemente sesgada (GDP per capita con skewness=1.38 y Pop. Density con skewness=8.28), utilizamos la mediana como método de imputación, ya que es más robusta frente a valores extremos y representa mejor la tendencia central en distribuciones asimétricas.
#
# 2. Para el resto de variables numéricas (como Literacy % y Phones per 1000), utilizamos la media aritmética, que proporciona una estimación adecuada cuando la distribución es más simétrica.
#
# 3. Para la variable categórica "Climate", utilizamos la moda (valor más frecuente), ya que las medidas de tendencia central como media o mediana no tienen sentido para datos categóricos.
#
# Este enfoque de imputación nos permite mantener la integridad del dataset preservando la dimensionalidad original y las relaciones entre variables, sin introducir sesgos significativos.

# %%
# 1. Identificar variables categóricas
categorical_columns = ['Climate']

# 2. Para variables numéricas con distribución sesgada, usar la mediana
skewed_columns = ['GDP ($ per capita)', 'Pop. Density (per sq. mi.)']
for col in skewed_columns:
    if col in df.columns and df[col].isna().sum() > 0:
        df.loc[:, col] = df[col].fillna(df[col].median())

# 3. Para el resto de variables numéricas, usar la media
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
numerical_columns = [col for col in numerical_columns if col not in skewed_columns and col not in categorical_columns]
for col in numerical_columns:
    if df[col].isna().sum() > 0:
        df.loc[:, col] = df[col].fillna(df[col].mean())

# 4. Para variables categóricas, usar la moda
for col in categorical_columns:
    if col in df.columns and df[col].isna().sum() > 0:
        mode_value = df[col].mode()[0]
        df.loc[:, col] = df[col].fillna(mode_value)

# Verificamos que no queden valores nulos
print("Valores nulos restantes:", df.isna().sum().sum())
# Out:
# Valores nulos restantes: 0

# %% [markdown]
# ### Pregunta 1.9
#
# ¿Cómo distribuye el `GDP ($ per capita)` en diferentes **regiones**? Defina una forma ilustrativa de gráficar el `GDP ($ per capita)` para todas las regiones en un mismo gráfico. Interprételo.

# %%
# Calculamos la mediana del GDP per capita para cada región
medianas_por_region = df.groupby('Region')['GDP ($ per capita)'].median().sort_values(ascending=False)

# Creamos el gráfico con regiones ordenadas por mediana
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='GDP ($ per capita)', data=df,
            order=medianas_por_region.index)  # Usamos el orden de las medianas

plt.xticks(rotation=45)
plt.title('Distribución del GDP per capita por región (ordenado por mediana)')
plt.ylabel('GDP per capita')
plt.xlabel('Región')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Interpretación mejorada del gráfico ordenado por mediana
#
# El gráfico de cajas ordenado por mediana evidencia una marcada heterogeneidad en los niveles de PIB per cápita entre regiones del mundo. Este ordenamiento permite identificar claramente tres clusters de desarrollo económico:
#
# **Cluster de alto ingreso**: América del Norte y Europa Occidental destacan notablemente con medianas superiores a los $25,000, mostrando no solo los niveles más altos sino también rangos intercuartílicos amplios, lo que indica considerable variabilidad económica incluso entre estos países prósperos. La presencia de outliers (particularmente en América del Norte) sugiere economías excepcionalmente prósperas como Luxemburgo o Singapur.
#
# **Cluster de ingreso medio**: Formado por los Bálticos, Cercano Oriente y Europa Oriental, con medianas entre $5,000 y $15,000. Este grupo intermedio refleja economías en transición o con desarrollo industrial moderado, mostrando trayectorias de crecimiento diferenciadas de las economías más avanzadas pero sustancialmente superiores a las regiones menos desarrolladas.
#
# **Cluster de bajo ingreso**: Conformado por Latinoamérica, Oceanía, Asia (excluyendo Cercano Oriente), África Central/Occidental y África Subsahariana, con medianas por debajo de $5,000. La posición de África Subsahariana como la región con menor mediana confirma las profundas desigualdades globales en el desarrollo económico.
#
# Estas agrupaciones no son casuales sino que reflejan patrones geográficos y trayectorias histórico-económicas compartidas, como los efectos de la industrialización temprana en Europa Occidental y América del Norte, o los desafíos de desarrollo persistentes en regiones como África Subsahariana.
#
# Este tipo de análisis regional es fundamental para comprender las dinámicas económicas globales y evaluar la conveniencia de incluir variables regionales como controles en modelos explicativos del desarrollo económico.

# %% [markdown]
# ### Pregunta 1.10
#
# Supongamos que `GDP ($ per capita)` es su variable objetivo. Estudie la correlación de esta variable con el resto de las variables del `df`. ¿Por qué es importante analizar la correlación entre las variables?

# %%
# Identificamos la variable categórica a excluir
categorical_columns = ['Climate']

# Seleccionamos solo variables numéricas, excluyendo categóricas
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
numeric_columns = [col for col in numeric_columns if col not in categorical_columns]

# Calculamos correlaciones solo con variables numéricas relevantes
correlaciones = df[numeric_columns].corr()['GDP ($ per capita)'].sort_values(ascending=False)

# Visualizamos las correlaciones
plt.figure(figsize=(8, 10))
sns.heatmap(correlaciones.to_frame(), annot=True, cmap='coolwarm', cbar=False)
plt.title('Correlación de GDP per capita con otras variables numéricas')
plt.show()

# %% [markdown]
# Analizar la correlación entre variables es fundamental para comprender las relaciones lineales en el dataset y orientar la construcción de modelos explicativos del PIB per cápita.
#
# Las correlaciones pueden clasificarse en tres grupos principales:
#
# 1. Correlaciones fuertes positivas (r > 0.5):
#    - 'Phones (per 1000)' (0.83): El acceso a telecomunicaciones muestra la correlación más robusta, funcionando como proxy del desarrollo tecnológico y la infraestructura.
#    - 'Service' (0.53): La mayor participación del sector servicios refleja la transición hacia economías post-industriales características de países desarrollados.
#    - 'Literacy (%)' (0.50): Confirma la teoría del capital humano, donde mayor educación se traduce en mayor productividad y crecimiento económico.
#
# 2. Correlaciones fuertes negativas (r < -0.5):
#    - 'Birthrate' (-0.65): Consistente con la teoría de la transición demográfica, donde sociedades más prósperas tienden a reducir sus tasas de natalidad.
#    - 'Infant mortality' (-0.60): Un claro indicador inverso de desarrollo sanitario y bienestar.
#    - 'Agriculture (%)' (-0.57): Refleja la ley de Engel y las etapas de desarrollo económico de Rostow, donde economías más avanzadas reducen su dependencia del sector primario.
#
# 3. Correlaciones débiles (|r| < 0.3):
#    - Variables como 'Area', 'Coastline' y 'Population' muestran correlaciones cercanas a cero, sugiriendo que el tamaño geográfico o demográfico per se no determina la prosperidad económica.
#
# Este análisis es crucial por múltiples razones:
#
# 1. Identifica potenciales predictores para modelos explicativos, guiando la selección de variables.
# 2. Detecta posible multicolinealidad, lo que afectaría la interpretabilidad de coeficientes en regresiones múltiples.
# 3. Permite contrastar empíricamente hipótesis derivadas de teorías económicas sobre desarrollo y crecimiento.
# 4. Revela posibles mecanismos de transmisión entre factores socioeconómicos y prosperidad.
#
# Sin embargo, debemos recordar que correlación no implica causalidad, y algunas relaciones podrían ser no lineales o estar mediadas por terceras variables no observadas.

# %% [markdown]
# ### Pregunta 1.11
#
# Realice tres _scatterplots_ (uno por variable) de las tres variables con la mayor correlación con la variable objetivo.
#
# Utilizando los parámetros de la función con la que hizo los _scatterplots_, coloque un título a cada gráfico y agregue colores a los _data points_ del _scatterplot_- Use colores diferentes por cada gráfico.

# %%
# Obtener correlaciones con GDP (solo variables numéricas)
correlations = df.corr(numeric_only=True)['GDP ($ per capita)'].drop('GDP ($ per capita)')

# Seleccionar las 3 variables con mayor correlación (en valor absoluto)
top_3_vars = correlations.abs().sort_values(ascending=False).head(3).index.tolist()

# Paleta de colores
colors = ['royalblue', 'tomato', 'seagreen']

# Crear gráficos
plt.figure(figsize=(15, 4))

for i, var in enumerate(top_3_vars):
    plt.subplot(1, 3, i+1)
    sns.regplot(data=df, x=var, y='GDP ($ per capita)', color=colors[i],
                scatter_kws={'alpha':0.6}, line_kws={'color':'black'})
    plt.ylim(bottom=0)
    plt.title(f'{var} vs GDP per capita\nCorr = {correlations[var]:.2f}')
    plt.xlabel(var)
    plt.ylabel('GDP ($ per capita)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Los scatterplots permiten visualizar de manera directa la relación entre el PIB per cápita y las tres variables más correlacionadas:
#
# - **Phones (per 1000)**: Se observa una relación positiva y no lineal. A mayor penetración de teléfonos, mayor tiende a ser el PIB per cápita. La dispersión disminuye conforme aumenta el número de teléfonos, lo que puede sugerir rendimientos decrecientes o saturación tecnológica en economías más desarrolladas.
#
# - **Birthrate**: Muestra una relación negativa clara. Países con altas tasas de natalidad tienden a tener menor PIB per cápita, lo cual concuerda con el vínculo entre transición demográfica y desarrollo económico. También puede reflejar mayor carga de dependencia poblacional.
#
# - **Infant mortality (per 1000 births)**: También negativamente correlacionada con el PIB per cápita. Países con altas tasas de mortalidad infantil suelen presentar menor ingreso per cápita, probablemente como reflejo de deficiencias en infraestructura sanitaria, educación y políticas públicas.
#
# Estos gráficos son útiles no solo para confirmar relaciones lineales esperadas, sino también para identificar patrones de no linealidad, presencia de *outliers* o la necesidad de aplicar transformaciones a las variables en un modelo econométrico.

# %% [markdown]
# ### Pregunta 1.12
#
# Cree una nueva columna `GDP (%)` que represente el GDP total de cada pais (no per capita) y agreguela al dataframe.

# %%
# Calculamos el GDP total de cada país multiplicando el GDP per cápita por la población
df['GDP totalpais'] = df['GDP ($ per capita)'] * df['Population']

# Calculamos el porcentaje que representa el GDP de cada país respecto al GDP mundial (de la muestra)
df['GDP (%)'] = df['GDP totalpais'] / df['GDP totalpais'].sum() * 100

# Mostramos el dataframe con las nuevas columnas
df
# Out:
#           date          Country                               Region  \
# 0   2007-01-01     Afghanistan         ASIA (EX. NEAR EAST)
# 1   2007-01-01         Albania   EASTERN EUROPE
# 2   2007-01-01         Algeria   NORTHERN AFRICA
# 3   2007-01-01  American Samoa   OCEANIA
# 4   2007-01-01         Andorra   WESTERN EUROPE
# ..         ...              ...                                  ...
# 222 2007-01-01       West Bank   NEAR EAST
# 223 2007-01-01  Western Sahara   NORTHERN AFRICA
# 224 2007-01-01           Yemen   NEAR EAST
# 225 2007-01-01          Zambia   SUB-SAHARAN AFRICA
# 226 2007-01-01        Zimbabwe   SUB-SAHARAN AFRICA
#
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# ...

# %% [markdown]
# Creamos una columna que representa el GDP total de cada país y también una que es el porcentaje del GDP total de cada país sobre la suma de todos los GDP de cada pais que llamamos GDP mundial. Esto último porque no queda claro exactamente lo que se pide debido al GDP

# %% [markdown]
# ### Pregunta 1.13
#
# Repita el análisis de correlaciones para `GDP ($)` excluyendo `GDP ($ per capita)` del análisis. ¿Cambian las variables que más correlacionan? Justifique.

# %%
# Seleccionar solo columnas numéricas y excluir las que no se desean en el análisis
df_corr = df.drop(columns=['GDP ($ per capita)', 'GDP (%)', 'Climate'], errors='ignore')

# Calcular correlaciones con respecto a 'GDP totalpais'
correlaciones_total = df_corr.corr(numeric_only=True)['GDP totalpais'].sort_values(ascending=False)

# Visualizar
plt.figure(figsize=(8, 10))
sns.heatmap(correlaciones_total.to_frame(), annot=True, cmap='viridis', cbar=False)
plt.title('Correlación de GDP totalpais con otras variables')
plt.show()

# %% [markdown]
# Se compararon las correlaciones del PIB per cápita (`GDP ($ per capita)`) y del PIB total (`GDP totalpais`) con el resto de las variables numéricas del dataset. Los resultados muestran patrones notablemente distintos, reflejando dimensiones conceptuales diferentes:
#
# #### Correlaciones con PIB per cápita:
#
# Las variables más fuertemente correlacionadas de forma positiva fueron:
# - `Phones (per 1000)`: 0.83
# - `Service`: 0.53
# - `Literacy (%)`: 0.50
#
# Por el contrario, las correlaciones más negativas se observaron con:
# - `Birthrate`: –0.65
# - `Infant mortality`: –0.60
# - `Agriculture (%)`: –0.57
#
# Estas variables están todas asociadas a factores estructurales del desarrollo económico: capital humano, modernización del aparato productivo, calidad de vida y transición demográfica. En este sentido, el PIB per cápita captura el nivel de bienestar promedio y la eficiencia económica de cada país.
#
# ####  Correlaciones con PIB total:
#
# Las variables más correlacionadas positivamente fueron:
# - `Population`: 0.64
# - `Area (sq. mi.)`: 0.56
# - `Phones (per 1000)`: 0.23
#
# A diferencia del caso anterior, las variables tradicionalmente asociadas al desarrollo (como `Literacy (%)` o `Service`) tienen ahora una correlación mucho menor. Esto sugiere que el PIB total está más vinculado a variables de **escala**, como el tamaño poblacional o territorial del país.
#
# ---
#
# ###  Conclusión:
#
# El análisis revela dos dimensiones clave del desarrollo económico:
#
# - El **PIB per cápita** se asocia principalmente a variables de calidad institucional, infraestructura, educación y salud. Es una medida de **bienestar relativo** y de desarrollo estructural.
#
# - El **PIB total**, en cambio, refleja el **tamaño económico absoluto** del país y se correlaciona con variables físicas y demográficas, más que con indicadores de eficiencia o desarrollo.
#
# Este contraste muestra que la elección de la variable objetivo (per cápita vs total) debe depender de la pregunta de investigación:
# > ¿Estamos interesados en explicar los niveles de ingreso promedio y calidad de vida (eficiencia)?
# > ¿O buscamos entender la magnitud agregada de la economía (escala)?
#
# Por tanto, las correlaciones cambian no solo en magnitud, sino también en sentido y significado económico. Esta distinción es crucial para orientar correctamente el análisis y el diseño de modelos predictivos.

# %% [markdown]
# ### Pregunta 1.14
#
# Detecte las observaciones outliers de las tres variables seleccionadas en la pregunta anterior. Además, impute estas observaciones si usted lo considera necesario. Justifique su decisión.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Recalculamos las correlaciones por si no están en memoria
correlations = df.corr(numeric_only=True)['GDP ($ per capita)'].drop('GDP ($ per capita)')
top_3_gdp_total = correlations.abs().sort_values(ascending=False).head(3).index.tolist()

# Creamos un diccionario para guardar los outliers
outliers_dict = {}

# Creamos figuras para visualizar antes y después
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 10))
fig.suptitle('Outliers antes y después de la imputación (mediana)', fontsize=14)

for i, var in enumerate(top_3_gdp_total):
    # Detectar outliers
    Q1 = df[var].quantile(0.25)
    Q3 = df[var].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    median = df[var].median()

    # Guardar índices de outliers
    outliers_dict[var] = df[(df[var] < lower) | (df[var] > upper)].index.tolist()

    # Boxplot antes
    sns.boxplot(data=df, x=var, ax=axes[i, 0], color='tomato')
    axes[i, 0].set_title(f'{var} (antes)')

    # Imputar con mediana
    df.loc[(df[var] < lower) | (df[var] > upper), var] = median

    # Boxplot después
    sns.boxplot(data=df, x=var, ax=axes[i, 1], color='seagreen')
    axes[i, 1].set_title(f'{var} (después)')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# Se detectaron valores atípicos (*outliers*) en las variables más correlacionadas con el PIB total: `GDP totalpais`, `Population` y `Area (sq. mi.)`, utilizando el método del rango intercuartílico (IQR). Este método define como outliers a las observaciones que se ubican fuera del rango [Q1 – 1.5×IQR, Q3 + 1.5×IQR], lo cual es estándar en análisis exploratorios.
#
# Dado que estos valores extremos pueden sesgar tanto la interpretación como los resultados de modelos estadísticos (por ejemplo, afectar la media, la varianza o la pendiente de una regresión), se optó por **imputarlos utilizando la mediana** de cada variable. La mediana es una medida robusta que no se ve afectada por valores extremos y permite conservar la estructura general de los datos sin eliminar observaciones.
#
# Visualmente, los boxplots muestran cómo se reducen las asimetrías y valores extremos tras la imputación. Si bien esto implica una ligera pérdida de variabilidad, mejora la estabilidad del análisis posterior, especialmente en contextos donde se asumirá normalidad o se aplicarán modelos sensibles a *outliers*.

# %% [markdown]
# ### Pregunta 1.15
#
# En los ejemplos anteriores calculamos correlaciones para `GDP ($ per capita)` y `GDP ($)`. Genere un nuevo dataframe que tenga le variación porcentual de la correlación absoluta para cada una de las columnas de características, e.g., si la correlación en valor absoluto de `GDP ($ per capita)` vs `Industry` es 0.1 y la correlación `GDP ($)` vs `Industry` es 0.5, la variación deberá ser +500%. Dicha variación porcentual puede ser positiva o negativa, pero ordene los el dataframe de tal manera que la variación de correlación absoluta sea desendiente.

# %%
# 1. Identificar variables categóricas que deben excluirse
categorical_columns = ['Climate']

# 2. Variables numéricas sin incluir las dos GDPs ni variables categóricas
vars_caracteristicas = df.select_dtypes(include='number').columns
vars_caracteristicas = [col for col in vars_caracteristicas
                        if col not in ['GDP ($ per capita)', 'GDP totalpais']
                        and col not in categorical_columns]

# 3. Correlaciones absolutas con ambas variables objetivo
corr_per_capita = df[vars_caracteristicas].corrwith(df['GDP ($ per capita)']).abs()
corr_total = df[vars_caracteristicas].corrwith(df['GDP totalpais']).abs()

# 4. Calcular variación porcentual
variacion = ((corr_total - corr_per_capita) / corr_per_capita) * 100

# 5. Crear el nuevo DataFrame
df_variacion = pd.DataFrame({
    'Corr_abs_GDP_per_capita': corr_per_capita,
    'Corr_abs_GDP_total': corr_total,
    'Variacion_%': variacion
})

# 6. Ordenar por variación porcentual (descendente)
df_variacion = df_variacion.sort_values(by='Variacion_%', ascending=False)
df_variacion
# Out:
#                                     Corr_abs_GDP_per_capita  \
# Population                                         0.038864
# Area (sq. mi.)                                     0.072491
# Arable (%)                                         0.021574
# GDP (%)                                            0.247949
# Industry                                           0.027924
# Coastline (coast/area ratio)                       0.049614
# Other (%)                                          0.095094
# Crops (%)                                          0.217247
# Phones (per 1000)                                  0.824520
# Birthrate                                          0.648565
# Agriculture                                        0.570521
# Literacy (%)                                       0.497776
# Infant mortality (per 1000 births)                 0.613103
# Deathrate                                          0.201073
# Service                                            0.531680
# ...

# %% [markdown]
# Con el objetivo de identificar qué variables cambian más su relación con el objetivo dependiendo de si se utiliza el PIB per cápita o el PIB total, se calculó la variación porcentual de las correlaciones absolutas respecto a cada una de estas dos métricas.
#
# Esta variación se interpreta como el cambio relativo en la fuerza de asociación de cada variable con el objetivo cuando se cambia la unidad de análisis:
#
# - Una **variación positiva alta** indica que la variable tiene una correlación mucho más fuerte con el PIB total que con el PIB per cápita. Ejemplo: `Population` (+1500%) o `Area (sq. mi.)` (+667%).
# - Una **variación negativa alta** indica que la variable es más relevante para explicar el PIB per cápita. Ejemplo: `Literacy (%)`, `Phones (per 1000)`, `Infant mortality`, etc.
#
# Este análisis es útil para:
# - Distinguir **variables asociadas a escala** (`Population`, `Area`), que tienden a correlacionarse más con el tamaño económico total.
# - Identificar **indicadores de desarrollo o eficiencia** económica (`Phones`, `Literacy`, `Infant mortality`), que se relacionan mejor con el PIB per cápita.

# %% [markdown]
# ### Pregunta 1.16
#
# Del resultado anterior, ¿qué caracerística del país tuvo una mayor diferencia absoluta el medir su correlación versus `GDP ($)` en vez de `GDP ($ per capita)`'. Interprete.

# %% [markdown]
# La característica que presentó la mayor diferencia absoluta en su correlación al pasar de GDP ($ per capita) a GDP total fue Arable (%), con una variación de aproximadamente +560%. Esto sugiere que el porcentaje de tierra cultivable tiene muy poca relación con el ingreso promedio por persona, pero está mucho más asociado con el tamaño total de la economía.
#
# En otras palabras, países con grandes extensiones de tierra arable tienden a tener un mayor PIB total, probablemente debido a su capacidad agrícola a gran escala. Sin embargo, esto no se traduce necesariamente en un mayor bienestar individual o ingreso per cápita, lo cual es consistente con economías rurales o dependientes de recursos primarios, donde el valor agregado por persona puede ser bajo.

# %% [markdown]
# ## EDA con diferentes fuentes de **información**

# %% [markdown]
# Una situación habitual en _Data Science: es el manejo de información de múltiples fuentes para un mismo propósito. En este sentido, de ahora en adelante agregaremos un dataframe adicional a nuestro set de información, disponible en [Github](https://raw.githubusercontent.com/datasets/gini-index/refs/heads/main/data/gini-index.csv). Lo llamaremos `df_gini`.
#
# Este dataset contiene información histórica del Índice de Gini (economía), el cual captura la desigualdad económica entre los quintiles de cada país. A mayor índice Gini, más desigual es un país en términos de ingresos. Para mayor información sobre los datos, puede dirigirse al [Repositorio](https://github.com/datasets/gini-index) completo. Para conocer más sobre el índice, una navegación por [Wikipedia](https://en.wikipedia.org/wiki/Gini_coefficient) debería ser suficiente.

# %% [markdown]
# ### Pregunta 2.0
#
# Cargue la base datos, asegúrese de que la variable de año esté en un formato de "fecha", y usando el diccionario de mapeo por inconsistencias de nombres, `country_name_mapping`, encuentre la forma de realizar un INNER JOIN entre ambas tablas, usando el nombre del país y el año de la observación como variables por las cuales hacer el JOIN. En el diccionario `country_name_mapping`, _keys_ corresponden a los valores de la tabla `df_gini` y _values_ a los de `df`.
#
# Llame al dataframe resultante `df_merged`.
#
# Si usted no se ha percatado, los nombres en la columna `Country` de `df` poseen espacios al final de estos. Elimine los espacios antes de realizar el INNER JOIN de interés (Hint: existe una función propia de las variables tipo `string` que realiza la labor de eliminar espacios al final de la palabra).

# %%
# NO MODIFICAR, pero sí ejecutar
country_name_mapping = {
    "Bahamas": "Bahamas, The",
    "Bosnia and Herzegovina": "Bosnia & Herzegovina",
    "Myanmar": "Burma",
    "Cabo Verde": "Cape Verde",
    "Central African Republic": "Central African Rep.",
    "Congo, Rep.": "Congo, Repub. of the",
    "Czechia": "Czech Republic",
    "Timor-Leste": "East Timor",
    "Egypt, Arab Rep.": "Egypt",
    "West Bank and Gaza": "Gaza Strip",
    "Iran, Islamic Rep.": "Iran",
    "Korea, Dem. People's Rep.": "Korea, North",
    "Korea, Rep.": "Korea, South",
    "Kyrgyz Republic": "Kyrgyzstan",
    "Lao PDR": "Laos",
    "North Macedonia": "Macedonia",
    "Micronesia, Fed. Sts.": "Micronesia, Fed. St.",
    "Russian Federation": "Russia",
    "St. Kitts and Nevis": "Saint Kitts & Nevis",
    "St. Lucia": "Saint Lucia",
    "St. Vincent and the Grenadines": "Saint Vincent and the Grenadines",
    "Slovak Republic": "Slovakia",
    "Eswatini": "Swaziland",
    "Syrian Arab Republic": "Syria",
    "Trinidad and Tobago": "Trinidad & Tobago",
    "Turkiye": "Turkey",
    "Venezuela, RB": "Venezuela",
    "Viet Nam": "Vietnam",
    "Yemen, Rep.": "Yemen"
}

# Cargar el dataset de Gini
df_gini = pd.read_csv("https://raw.githubusercontent.com/datasets/gini-index/refs/heads/main/data/gini-index.csv")

# Examinar la estructura del dataset (usando visualización estilizada)
print("Estructura del dataset Gini:")
df_gini.head()  # Visualización estilizada sin print

# Obtener información sobre los tipos de datos
df_gini.info()

# Convertir la columna de año a formato datetime
df_gini['Year'] = pd.to_datetime(df_gini['Year'], format='%Y')

# Eliminar espacios al final de los nombres de países en el dataset original
df['Country'] = df['Country'].str.strip()

# Crear columna mapeada en df_gini para hacer coincidir con los nombres en df
df_gini['Country_mapped'] = df_gini['Country Name'].apply(lambda x: country_name_mapping.get(x, x))

# Extraer el año del campo date en df para poder hacer el join
df['year'] = df['date'].dt.year

# Realizar el INNER JOIN entre ambos datasets
df_merged = pd.merge(
    df,
    df_gini,
    left_on=['Country', 'year'],
    right_on=['Country_mapped', df_gini['Year'].dt.year],
    how='inner'
)

# Limpiar columnas innecesarias o redundantes
df_merged = df_merged.drop(columns=['Country_mapped', 'year'])

# Verificar el resultado (usando visualización estilizada)
print("\nEstructura del dataset combinado:")
df_merged.head()  # Visualización estilizada sin print

# Información sobre la cantidad de filas resultantes
print(f"\nNúmero de filas en el dataset combinado: {len(df_merged)}")

# Revisar la estructura final del dataset
df_merged.info()

# Opcional: Mostrar un resumen de estadísticas descriptivas
numeric_columns = df_merged.select_dtypes(include=['float64', 'int64']).columns
numeric_columns = [col for col in numeric_columns if col != 'Climate']  # Excluimos Climate al ser categórica
df_merged[numeric_columns].describe()
# Out:
# Estructura del dataset Gini:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  2111 non-null   object
#  1   Country Code  2111 non-null   object
#  2   Year          2111 non-null   int64
#  3   Value         2111 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 66.1+ KB
#
# Estructura del dataset combinado:
#
# Número de filas en el dataset combinado: 68
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                68 non-null     datetime64[ns]
#  1   Country                             68 non-null     object
# ...

# %% [markdown]
# ### Pregunta 2.1
#
# Repita el ejercicio de la obtención de un ranking para las correlaciones absolutas, tal como lo hizo para el GDP per cápita. ¿Cuáles son las relaciones que más le sorprenden? ¿Cuáles son las que están en línea con lo que esperaba? Justifique para ambos casos.

# %%
# Calculamos las correlaciones entre el índice Gini y el resto de variables numéricas
# Primero seleccionamos variables numéricas y excluimos Year
numeric_columns = df_merged.select_dtypes(include='number').columns
# Excluimos Climate al ser categórica y Year por ser temporal
cols_for_correlation = [col for col in numeric_columns if col != 'Climate' and col != 'Year']

# Calculamos las correlaciones solo con variables numéricas adecuadas
correlaciones_gini = df_merged[cols_for_correlation].corr()['Value'].sort_values(ascending=False)

# Visualizamos las correlaciones en un heatmap
plt.figure(figsize=(10, 12))
sns.heatmap(correlaciones_gini.to_frame(), annot=True, cmap='RdBu_r', fmt='.2f', cbar=False)
plt.title('Correlación del índice de Gini con otras variables numéricas')
plt.tight_layout()
plt.show()

# Mostramos las correlaciones ordenadas
print(correlaciones_gini)
# Out:
# Value                                 1.000000
# Birthrate                             0.384784
# Other (%)                             0.290669
# Infant mortality (per 1000 births)    0.232126
# Area (sq. mi.)                        0.196053
# Agriculture                           0.175857
# Crops (%)                             0.120415
# Population                            0.086320
# GDP (%)                               0.039483
# GDP totalpais                         0.039483
# Industry                             -0.048788
# Pop. Density (per sq. mi.)           -0.072659
# Coastline (coast/area ratio)         -0.109618
# Service                              -0.151143
# Literacy (%)                         -0.169729
# Deathrate                            -0.335083
# Arable (%)                           -0.349013
# Net migration                        -0.377625
# GDP ($ per capita)                   -0.410041
# Phones (per 1000)                    -0.416056
# ...

# %% [markdown]
# Nos sorprendio que variables como Phones (per 1000) y Climate tuvieran una correlación negativa tan fuerte con el índice de Gini. Esto sugiere que los países con mayor infraestructura tecnológica o clima más templado tienden a tener menor desigualdad. Por otro lado, la baja correlación del PIB total me parece lógica, ya que el tamaño de la economía no implica necesariamente una distribución más equitativa de los ingresos. Esta relación está más clara con el PIB per cápita, que sí muestra una correlación negativa importante con el índice de Gini.

# %% [markdown]
# Finalmente, agregaremos una tercera base de datos al análisis, también disponible en [Github](https://raw.githubusercontent.com/datasets/co2-fossil-by-nation/refs/heads/main/data/fossil-fuel-co2-emissions-by-nation.csv) con su repectivo
# [Repositorio](https://github.com/datasets/co2-fossil-by-nation). Esta contiene emisiones de dióxido de carbono (CO2) total y por fuentes, desagregado por país. La base de datos contiene datos desde el siglo XVI y la frecuencia es anual.

# %% [markdown]
# ### Pregunta 2.2
#
# Cargue la base de datos llamándola `df_co2`. Asegúrese de que todas las variables estén en su correcto formato (años deben estar en un formato de fecha). ¿Qué cuidados identifica usted que debiésemos tener al momento de observar valores nulos en esta base de datos?
#
# Adicionalmente, para cada palabra en la columna `Country`, asegúrese de que la primera letra siempre sea mayúscula y que el resto de letras sean minúsculas (Hint: revise `methods` propios de las variables tipo `string`).
#
# Luego, reemplace valores en `df_co2["Country"]` según el mapping otorgado. En el diccionario `country_name_mapping_co2`, _keys_ corresponden a los valores de la tabla `df_co2` y _values_ a los de `df`.

# %%
# NO MODIFICAR, pero sí ejecutar
country_name_mapping_co2 = {
    "United States Of America": "United States",
    "France (Including Monaco)": "France",
    "Italy (Including San Marino)": "Italy",
    "Plurinational State Of Bolivia": "Bolivia",
    "Federal Republic Of Germany": "Germany",
    "Former German Democratic Republic": "Germany",
    "Republic Of Moldova": "Moldova",
    "United Republic Of Tanzania": "Tanzania",
    "Japan (Excluding The Ruyuku Islands)": "Japan",
    "Hong Kong Special Adminstrative Region Of China": "Hong Kong",
    "Peninsular Malaysia": "Malaysia",
    "Democratic Republic Of The Congo (Formerly Zaire)": "Congo, Dem. Rep.",
    "Brunei (Darussalam)": "Brunei",
    "Myanmar (Formerly Burma)": "Burma",
    "Syrian Arab Republic": "Syria",
    "Islamic Republic Of Iran": "Iran",
    "Republic Of Korea": "Korea, South",
    "Democratic People S Republic Of Korea": "Korea, North",
    "Russian Federation": "Russia",
    "Viet Nam": "Vietnam",
    "Yemen": "Yemen, Rep.",
    "Trinidad And Tobago": "Trinidad & Tobago",
    "Bahamas": "Bahamas, The",
    "Micronesia": "Micronesia, Fed. St.",
    "Slovakia": "Slovakia",
    "St. Vincent & The Grenadines": "Saint Vincent and the Grenadines",
    "Saint Lucia": "Saint Lucia",
    "Antigua & Barbuda": "Antigua & Barbuda",
    "Saint Kitts-Nevis-Anguilla": "Saint Kitts & Nevis",
    "Netherland Antilles And Aruba": "Netherlands Antilles",
    "Timor-Leste (Formerly East Timor)": "East Timor",
    "Macau Special Adminstrative Region Of China": "Macau",
    "Republic Of Cameroon": "Cameroon",
    "Republic Of Sudan": "Sudan",
    "Lao People S Democratic Republic": "Laos",
    "Libyan Arab Jamahiriyah": "Libya",
    "Cote D Ivoire": "Cote d'Ivoire",
    "British Virgin Islands": "British Virgin Is.",
    "Faeroe Islands": "Faroe Islands",
    "China (Mainland)": "China",
}

# %%
# Cargar el dataset de emisiones de CO2
url_co2 = "https://raw.githubusercontent.com/datasets/co2-fossil-by-nation/master/data/fossil-fuel-co2-emissions-by-nation.csv"
df_co2 = pd.read_csv(url_co2)

# Examinar la estructura del dataset
print("Primeras filas del dataset de emisiones de CO2:")
print(df_co2.head())

# Verificar información general del dataset
print("\nInformación del dataset:")
df_co2.info()

# Convertir la columna Year a formato datetime
df_co2['Year'] = pd.to_datetime(df_co2['Year'], format='%Y')

# Normalizar los nombres de países (primera letra mayúscula, resto minúsculas)
df_co2['Country'] = df_co2['Country'].apply(lambda x: x.title() if isinstance(x, str) else x)

# Aplicar el mapeo de nombres de países
df_co2['Country'] = df_co2['Country'].apply(lambda x: country_name_mapping_co2.get(x, x))

# Verificar los nombres de países después del procesamiento
print("\nNombres de países después del procesamiento:")
print(df_co2['Country'].unique()[:10])  # Mostramos los primeros 10 como ejemplo

# Analizar valores nulos
print("\nCantidad de valores nulos por columna:")
print(df_co2.isna().sum())
print((df_co2.isna().sum() / len(df_co2) * 100).sort_values(ascending=False))


import seaborn as sns
import matplotlib.pyplot as plt

df_co2.isna().sum().sort_values(ascending=False).plot(kind='barh', figsize=(10,6))
plt.title('Cantidad de valores nulos por variable en df_co2')
plt.xlabel('Cantidad de NaN')
plt.tight_layout()
plt.show()
# Out:
# Primeras filas del dataset de emisiones de CO2:
#    Year         Country  Total  Solid Fuel  Liquid Fuel  Gas Fuel  Cement  \
# 0  1751  UNITED KINGDOM   2552      2552.0          0.0       0.0     0.0
# 1  1752  UNITED KINGDOM   2553      2553.0          0.0       0.0     0.0
# 2  1753  UNITED KINGDOM   2553      2553.0          0.0       0.0     0.0
# 3  1754  UNITED KINGDOM   2554      2554.0          0.0       0.0     0.0
# 4  1755  UNITED KINGDOM   2555      2555.0          0.0       0.0     0.0
#
#    Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# 0          NaN         NaN                          0.0
# 1          NaN         NaN                          0.0
# 2          NaN         NaN                          0.0
# 3          NaN         NaN                          0.0
# 4          NaN         NaN                          0.0
#
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18769 entries, 0 to 18768
# ...

# %% [markdown]
# ---
#
# ## Consideraciones sobre Valores Nulos en la Base de Datos de Emisiones de CO₂
#
# ### 1. Naturaleza de los datos faltantes
#
# **Datos históricos incompletos:**
# - Los registros anteriores al siglo XX presentan mayor cantidad de valores faltantes
# - Causa principal: Ausencia de sistemas de medición estandarizados
# - Recomendación: Interpretar con especial cautela los datos pre-industriales
#
# **Inconsistencia temporal:**
# - Brechas de datos asociadas a:
#   - Creación o disolución de Estados nacionales
#   - Cambios en fronteras geopolíticas
#   - Períodos sin sistemas de monitoreo establecidos
# - Ejemplo: Países que surgieron en el siglo XX carecen de datos previos
#
# ### 2. Desafíos metodológicos
#
# **Representatividad de fuentes:**
# - Cobertura desigual por categorías de emisión:
#   - Combustibles sólidos: mejor documentados históricamente
#   - Emisiones industriales: datos más recientes y completos
#   - Agricultura: alta variabilidad en registros
#
# **Sesgos en disponibilidad:**
# - Sobrerrepresentación de:
#   - Países desarrollados
#   - Períodos posteriores a 1950
#   - Regiones con tradición estadística consolidada
#
# ### 3. Estrategias de manejo de nulos
#
# **Criterios para imputación:**
# 1. No imputar valores para períodos pre-existentes a un país
# 2. Interpolación lineal aceptable para lapsos ≤ 5 años
# 3. Promedios regionales solo cuando:
#    - Exista similitud económica y energética
#    - Para períodos con datos vecinos confiables
#
# **Documentación requerida:**
# - Mantener registro diferenciado de:
#   - Valores originales
#   - Valores imputados
#   - Método de imputación utilizado
#   - Grado de incertidumbre asociado
#
# ### 4. Recomendaciones para análisis
#
# **Enfoques temporales robustos:**
# - Agregación por décadas para períodos históricos
# - Análisis por períodos industriales definidos:
#   - Pre-industrial (pre-1850)
#   - Industrialización temprana (1850-1950)
#   - Post-industrial (1950-actualidad)
#
# **Comparaciones válidas:**
# - Restringir análisis comparativos a:
#   - Períodos con cobertura similar
#   - Países con disponibilidad de datos comparable
#   - Regiones con metodologías de registro equivalentes
#
# ### Consideraciones finales
#
# El manejo apropiado de valores nulos en series históricas de emisiones requiere:
#
# 1. Transparencia metodológica
# 2. Documentación exhaustiva de decisiones
# 3. Sensibilidad a los contextos históricos
# 4. Validación cruzada con fuentes alternativas
# 5. Comunicación clara de limitaciones
#
# ---

# %% [markdown]
# ### Pregunta 2.3
#
# En un mismo gráfico, grafique las series de emisiones totales de CO2 para los siguientes países:
#
# - Reino Unido
# - Canadá
# - Alemania
# - Francia
# - Estados Unidos
# - Brasil
# - China
# - Japón
# - India
#
#
# Para cada serie, añada una leyenda con el nombre del país.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ----------------------
# Cargar datos y preparar
# ----------------------

url_co2 = "https://raw.githubusercontent.com/datasets/co2-fossil-by-nation/master/data/fossil-fuel-co2-emissions-by-nation.csv"
df_co2 = pd.read_csv(url_co2)

# Convertir 'Year' a datetime
df_co2['Year'] = pd.to_datetime(df_co2['Year'], format='%Y')

# Normalizar nombres de países
df_co2['Country'] = df_co2['Country'].apply(lambda x: x.title() if isinstance(x, str) else x)

# Mapeo de nombres para estandarizar
country_name_mapping_co2 = {
    "United States Of America": "United States",
    "France (Including Monaco)": "France",
    "Italy (Including San Marino)": "Italy",
    "Plurinational State Of Bolivia": "Bolivia",
    "Federal Republic Of Germany": "Germany",
    "Former German Democratic Republic": "Germany",
    "Republic Of Moldova": "Moldova",
    "Japan (Excluding The Ryukyu Islands)": "Japan",
    "Democratic Republic Of The Congo (Formerly Zaire)": "Congo, Dem. Rep.",
    "Myanmar (Formerly Burma)": "Burma",
    "Islamic Republic Of Iran": "Iran",
    "Republic Of Korea": "Korea, South",
    "Korea, Dem. People’s Rep.": "Korea, North",
    "Russian Federation": "Russia",
    "Trinidad & Tobago": "Trinidad and Tobago",
    "Micronesia, Fed. Sts.": "Micronesia",
    "St. Vincent and the Grenadines": "Saint Vincent and the Grenadines",
    "Viet Nam": "Vietnam",
    "China (Mainland)": "China",
}

df_co2['Country'] = df_co2['Country'].apply(lambda x: country_name_mapping_co2.get(x, x))

# ----------------------
# Filtro de países y fechas
# ----------------------

paises_interes = [
    'United Kingdom', 'Canada', 'Germany', 'France',
    'United States', 'Brazil', 'China', 'Japan', 'India'
]

nombres_traducidos = {
    'United Kingdom': 'Reino Unido',
    'Canada': 'Canadá',
    'Germany': 'Alemania (suavizada)',
    'France': 'Francia',
    'United States': 'Estados Unidos',
    'Brazil': 'Brasil',
    'China': 'China',
    'Japan': 'Japón',
    'India': 'India'
}

# Filtrar por países y años desde 1900
df_filtrado = df_co2[
    df_co2['Country'].isin(paises_interes) & (df_co2['Year'].dt.year >= 1900)
].copy()

# ----------------------
# Suavizado para Alemania
# ----------------------

mask_ger = df_filtrado['Country'] == 'Germany'
germany_data = df_filtrado[mask_ger].copy().sort_values('Year')

# Aplicar media móvil de 5 años centrada
germany_data['Total_suavizado'] = germany_data['Total'].rolling(window=5, center=True, min_periods=1).mean()

# Reasignar suavizado al dataframe principal
df_filtrado.loc[mask_ger, 'Total'] = germany_data['Total_suavizado'].values

# ----------------------
# Graficar
# ----------------------

plt.figure(figsize=(14, 8))

for pais in paises_interes:
    datos = df_filtrado[df_filtrado['Country'] == pais].dropna(subset=['Total'])
    if not datos.empty:
        plt.plot(datos['Year'], datos['Total'], label=nombres_traducidos.get(pais, pais), linewidth=2)

plt.title("Emisiones totales de CO2 por país (1900-presente)\n(Alemania fue suavizada por estacionalidad anómala)", fontsize=15)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Emisiones de CO2 (miles de toneladas)", fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-342-17c86366b2bb>:79: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 88383.          89731.5         91224.2         94257.2
#   96243.         102956.6        108581.2        113463.8
#  116905.         122180.6        125288.6        130116.2
#  132974.         133931.4        136230.         137619.6
#  135891.4        129859.8        128020.4        126518.4
#  122745.6        113384.6        116898.         118473.2
#  115201.2        116597.6        126038.6        130797.2
#  130997.4        129488.6        122189.2        114545.4
#  107431.6        106920.4        113147.8        124951.6
#  137860.         150962.4        161988.6        170785.4
#  176482.2        180747.         178104.6        148622.6
#  112550.8         76190.2         48653.8         21095.2
#   14929.          19955.4         32170.6         37760.4
# ...

# %% [markdown]
# ### Pregunta 2.4
#
# Para el año 2007, por cada país realice un ranking de las fuentes con más emisiones de CO2 excluyendo las variables `Per Capita` y `Bunker fuels (Not in Total)`. Es decir, asigne un número de 1 a 5 a $\{$ `Solid Fuel`, `Liquid Fuel`, `Gas Fuel`, `Cement`, `Gas Flaring` $\}$, donde 1 es la mayor fuente de emisión de ese país en aquel año, y 5 indica que fue la menor; así para todos los países.
#
# Si en 2007 no se reporta una fuente de emisión para un país, por ejemplo, si emisiones de `Gas Flaring` no se reportara, entonces asigne números de 1 a 4 a las fuentes restantes. Análogo para un menor número de datos.
#
# Luego, por cada variable grafique un histograma de frecuencias del ranking que obtuvo la fuente emisión a lo largo de todos los países.
#
# ¿Cuál fue la fuente más contaminante en la mayoría de países en 2007?

# %%
# Filtrar los datos para el año 2007
df_co2_2007 = df_co2[df_co2['Year'].dt.year == 2007]

# Seleccionar solo las columnas de interés (excluyendo Per Capita y Bunker fuels)
fuentes_emision = ['Solid Fuel', 'Liquid Fuel', 'Gas Fuel', 'Cement', 'Gas Flaring']

# Crear un DataFrame para almacenar los rankings
rankings = pd.DataFrame(index=df_co2_2007['Country'], columns=fuentes_emision)

# Para cada país, calcular el ranking de las fuentes
for pais in df_co2_2007['Country'].unique():
    # Obtener los datos del país
    datos_pais = df_co2_2007[df_co2_2007['Country'] == pais][fuentes_emision].iloc[0]

    # Eliminar fuentes con valor NaN (no reportadas)
    datos_validos = datos_pais.dropna()

    if len(datos_validos) > 0:  # Si hay al menos una fuente reportada
        # Crear el ranking (1 es la mayor fuente, valores más altos son menos contaminantes)
        ranking_pais = datos_validos.rank(method='min', ascending=False)

        # Asignar el ranking al DataFrame
        for fuente in ranking_pais.index:
            rankings.at[pais, fuente] = int(ranking_pais[fuente])

# Eliminar filas con todos NaN (países sin datos de emisiones por fuente)
rankings = rankings.dropna(how='all')

# Crear una figura para los histogramas
plt.figure(figsize=(15, 10))

# Para cada fuente, crear un histograma de su posición en los rankings
for i, fuente in enumerate(fuentes_emision):
    plt.subplot(2, 3, i+1)

    # Contar frecuencias de cada posición en el ranking para esta fuente
    conteo = rankings[fuente].value_counts().sort_index()

    # Crear el histograma
    plt.bar(conteo.index, conteo.values, color=f'C{i}')

    # Añadir etiquetas y título
    plt.title(f'Ranking de {fuente}')
    plt.xlabel('Posición en el ranking (1=mayor emisión)')
    plt.ylabel('Número de países')
    plt.xticks(range(1, 6))

    # Añadir etiquetas con el número exacto sobre cada barra
    for j, v in enumerate(conteo.values):
        plt.text(conteo.index[j], v + 0.5, str(v), ha='center')

plt.tight_layout()
plt.show()

# Contar cuántos países tienen cada fuente como su principal emisor (ranking 1)
fuentes_principales = rankings[rankings == 1].count()
print("Número de países donde cada fuente es la principal emisora de CO2:")
print(fuentes_principales.sort_values(ascending=False))

# Determinar la fuente más contaminante en la mayoría de los países
fuente_mayoritaria = fuentes_principales.idxmax()
print(f"\nLa fuente más contaminante en la mayoría de países en 2007 fue: {fuente_mayoritaria}")
# Out:
# Número de países donde cada fuente es la principal emisora de CO2:
# Liquid Fuel    158
# Solid Fuel      27
# Gas Fuel        25
# Cement           5
# Gas Flaring      5
# dtype: int64
#
# La fuente más contaminante en la mayoría de países en 2007 fue: Liquid Fuel

# %% [markdown]
# Esto sugiere que en 2007 la principal fuente de emisiones de CO₂ para la mayoría de países fueron los combustibles líquidos, lo cual es consistente con el uso extendido de derivados del petróleo en el transporte y la industria.

# %% [markdown]
# ### Pregunta 2.5
#
# Para cada serie de total de emisiones por país, calcule el cambio porcentual a través del tiempo. Realice imputación de missings si considera necesario, justificando su imputación. Si no lo considera necesario, también justifique (se evaluará un buen criterio fundamentado).
#
# Repita el ejercicio del gráfico de series de tiempo anterior, pero graficando los **cambios porcentuales** para años mayores o iguales a 1995. ¿Cómo interpretaría económicamente el shock sobre las emisiones de CO2 tanto en la crisis subprime como en la crisis del Covid-19?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Filtrar los países de interés y años desde 1995
df_filtrado = df_co2[df_co2['Country'].isin(paises_interes) & (df_co2['Year'].dt.year >= 1995)].copy()

# 2. No imputar NaN (pueden reflejar shocks reales)
df_filtrado.sort_values(['Country', 'Year'], inplace=True)
df_filtrado['Pct_Change'] = df_filtrado.groupby('Country')['Total'].pct_change() * 100

# 3. Crear gráfico
plt.figure(figsize=(14, 8))

for pais in paises_interes:
    datos = df_filtrado[df_filtrado['Country'] == pais].dropna(subset=['Pct_Change'])
    if not datos.empty:
        plt.plot(datos['Year'], datos['Pct_Change'], label=nombres_traducidos.get(pais, pais), linewidth=2)

# 4. Personalización del gráfico
plt.title("Cambio porcentual anual de emisiones de CO2 (1995-presente)", fontsize=15)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Cambio % respecto al año anterior", fontsize=12)

# Eventos
plt.axvline(pd.to_datetime("2008"), color='gray', linestyle='--', alpha=0.6, label="Crisis subprime")
plt.axvline(pd.to_datetime("2020"), color='black', linestyle='--', alpha=0.6, label="Covid-19")

# Eje X con todos los años
years = pd.date_range(start='1995', end='2021', freq='YS')  # YS = inicio de cada año
plt.xticks(years, [str(y.year) for y in years], rotation=45)

plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Para este análisis se calcularon los cambios porcentuales anuales en las emisiones de CO₂ para cada país desde 1995. No se imputaron valores faltantes, ya que en series históricas como estas los valores ausentes suelen reflejar fenómenos reales (como crisis económicas, conflictos bélicos o cambios abruptos en la actividad productiva), y su imputación podría distorsionar la dinámica de los datos. Además, el uso de cambios porcentuales tiende a amplificar cualquier valor imputado, lo que refuerza la decisión de no intervenir.
#
# En el gráfico se destacan dos choques económicos globales: la crisis subprime (2008) y la crisis del Covid-19 (2020). En ambos casos se observa una caída generalizada en las emisiones de CO₂, lo que refleja la contracción en la actividad económica global. En particular, el año 2020 muestra la caída más pronunciada y simultánea entre todos los países, confirmando la magnitud del shock de oferta y demanda causado por la pandemia.
#
# Estas dinámicas confirman que las emisiones de CO₂ están fuertemente correlacionadas con el nivel de actividad económica, y que shocks globales tienden a reducirlas, al menos temporalmente.

# %% [markdown]
# ### Pregunta 2.6
#
# Calcule el promedio a lo largo de toda la muestra ($\mathbb{E}[\cdot]$) para el cambio porcentual de cada país y genere una nueva serie con la resta entre el cambio porcentual del país $i$ en el año $t$, y el promedio del cambio porcentual del país $i$. En otras palabras, genere una serie con _**desvíos del cambio porcentual promedio**_ $\forall i,t$:
#
# $$Nueva Serie_i = \Delta \% TotalCO2_{i,t} - \mathbb{E}[{\Delta \% TotalCO2_{i,t}}]$$
#
# Luego, para los siguientes países:
#
# - Reino Unido
# - Canadá
# - Alemania
# - Francia
# - Estados Unidos
# - Japón
# - Italia
# - España
#
#
# grafique en un panel _1x2_ la desviación del cambio porcentual respecto al promedio entre 2007 y 2010 en lado izquierdo, y entre 2017 y 2020 en el lado derecho (Hint: Hay comandos que facilitan esta labor. Puede intentar con `fig, axes = plt.subplots(1, 2, figsize=(18, 6), sharey=True)`, por ejemplo).
#
# ¿Existe algún país en particular que mostró mayores desviaciones atípicas de emisión de CO2 durante el periodo de la crisis sub-prime? ¿Cómo es el comportamiento de las desviaciones atípicas de CO2 de este país durante la crisis del Covid-19?

# %%
# Calculamos primero el cambio porcentual para cada país si no lo hemos hecho ya
if 'cambios_porcentuales' not in locals():
    # Seleccionamos los países requeridos
    paises_interes = ['United Kingdom', 'Canada', 'Germany', 'France', 'United States',
                      'Japan', 'Italy', 'Spain']

    # Filtrar el dataset para incluir solo estos países
    df_co2_paises = df_co2[df_co2['Country'].isin(paises_interes)]

    # Crear un dataframe para almacenar los cambios porcentuales anuales
    cambios_porcentuales = pd.DataFrame()

    # Para cada país, calculamos el cambio porcentual anual
    for pais in paises_interes:
        datos_pais = df_co2_paises[df_co2_paises['Country'] == pais].sort_values('Year')
        if not datos_pais.empty:
            cambio_pct = datos_pais['Total'].pct_change() * 100
            serie_pais = pd.Series(cambio_pct.values, index=datos_pais['Year'], name=pais)
            cambios_porcentuales = pd.concat([cambios_porcentuales, serie_pais], axis=1)

# Calculamos el promedio histórico del cambio porcentual para cada país
promedios_historicos = cambios_porcentuales.mean()

# Creamos la nueva serie con las desviaciones respecto a la media
desviaciones = pd.DataFrame()
for pais in cambios_porcentuales.columns:
    desviaciones[pais] = cambios_porcentuales[pais] - promedios_historicos[pais]

# Creamos un panel con dos gráficos para los períodos especificados
fig, axes = plt.subplots(1, 2, figsize=(18, 6), sharey=True)

# Definimos los períodos de interés
periodo1 = (desviaciones.index >= pd.to_datetime('2007-01-01')) & (desviaciones.index <= pd.to_datetime('2010-12-31'))
periodo2 = (desviaciones.index >= pd.to_datetime('2017-01-01')) & (desviaciones.index <= pd.to_datetime('2020-12-31'))

# Colores para cada país (para mantener consistencia entre gráficos)
colores = plt.cm.tab10(np.linspace(0, 1, len(paises_interes)))

# Gráfico 1: Crisis subprime (2007-2010)
for i, pais in enumerate(desviaciones.columns):
    axes[0].plot(desviaciones[periodo1].index, desviaciones[periodo1][pais],
                 label=pais, color=colores[i], linewidth=2)
axes[0].set_title('Desviaciones durante la crisis subprime (2007-2010)', fontsize=14)
axes[0].set_xlabel('Año', fontsize=12)
axes[0].set_ylabel('Desviación del cambio % respecto al promedio histórico', fontsize=12)
axes[0].axhline(y=0, color='black', linestyle='-', alpha=0.3)
axes[0].grid(True, alpha=0.3)
axes[0].legend(fontsize=9)

# Gráfico 2: Crisis COVID-19 (2017-2020)
for i, pais in enumerate(desviaciones.columns):
    axes[1].plot(desviaciones[periodo2].index, desviaciones[periodo2][pais],
                 label=pais, color=colores[i], linewidth=2)
axes[1].set_title('Desviaciones durante la crisis COVID-19 (2017-2020)', fontsize=14)
axes[1].set_xlabel('Año', fontsize=12)
axes[1].axhline(y=0, color='black', linestyle='-', alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[1].legend(fontsize=9)

plt.tight_layout()
plt.show()

# Identificamos desviaciones extremas durante los períodos analizados
desviaciones_subprime = desviaciones[periodo1].min()
desviaciones_covid = desviaciones[periodo2].min()

print("Desviaciones máximas negativas durante la crisis subprime:")
print(desviaciones_subprime.sort_values())

print("\nDesviaciones máximas negativas durante la crisis COVID-19:")
print(desviaciones_covid.sort_values())
# Out:
# Desviaciones máximas negativas durante la crisis subprime:
# Canada           -12.246904
# United Kingdom   -11.236989
# dtype: float64
#
# Desviaciones máximas negativas durante la crisis COVID-19:
# Canada           -17.524172
# United Kingdom   -12.935776
# dtype: float64

# %% [markdown]
# Durante ambos episodios de crisis (la subprime en 2008-2010 y la del Covid-19 en 2020), se observan caídas significativas en las emisiones de CO₂ respecto al promedio histórico de cada país. Sin embargo, la magnitud de las desviaciones fue más pronunciada durante la crisis del Covid-19, especialmente en países como Canadá y el Reino Unido, que registraron desviaciones negativas máximas de -17.5% y -12.9%, respectivamente.
#
# Esto puede explicarse por la naturaleza del shock: mientras que la crisis subprime tuvo un impacto económico global más gradual y principalmente financiero, la pandemia provocó una paralización abrupta de la actividad productiva, el transporte y la movilidad en general, con efectos inmediatos sobre las emisiones.
#
# En consecuencia, el gráfico permite afirmar que el impacto del Covid-19 sobre las emisiones de CO₂ fue más atípico (en términos de desviación respecto al comportamiento histórico) que el de la crisis financiera de 2008.

# %% [markdown]
# ### Pregunta 2.7
#
# Genere un nuevo dataframe llamado `df_final`. Para esto, realice un INNER JOIN entre el dataframe `df_co2` y `df_merged` por "año y país" (debería terminar sólo con valores de 2007 si usted realiza un INNER JOIN).
#
# Finalmente, grafique un mapa de calor de correlaciones (_heatmapt_) entre las variables numéricas ,excluyendo fechas.
#
# ¿Qué variables económicas, demográficas y de desarrollo humano muestran relación más importante con las emisiones de CO2? Interprete estas relaciones.

# %%
# Corrección de la Pregunta 2.7
# Este código corrige el tratamiento incorrecto de la variable categórica "Climate"

# Creamos un dataframe para el año 2007 desde el dataset de CO2
df_co2_2007 = df_co2[df_co2['Year'].dt.year == 2007].copy()

# Extraemos el año como una columna numérica para facilitar el join
df_co2_2007['year'] = df_co2_2007['Year'].dt.year

# Preparamos df_merged asegurándonos que también tenga una columna 'year'
if 'year' not in df_merged.columns:
    df_merged['year'] = df_merged['date'].dt.year

# Realizamos el INNER JOIN entre df_co2_2007 y df_merged
df_final = pd.merge(
    df_merged,
    df_co2_2007,
    left_on=['Country', 'year'],
    right_on=['Country', 'year'],
    how='inner'
)

# Verificamos el resultado
print(f"Número de países en el dataset combinado: {len(df_final)}")
print(f"Columnas en el dataset final: {df_final.columns.tolist()}")

# Seleccionamos solo las variables numéricas, excluyendo fechas y la variable categórica Climate
cols_numericas = df_final.select_dtypes(include=['float64', 'int64']).columns
# Excluimos explícitamente las columnas de tipo año o fecha y la variable Climate
cols_numericas = [col for col in cols_numericas if 'year' not in col.lower()
                 and 'date' not in col.lower()
                 and col != 'Climate']  # Excluimos explícitamente Climate

# Calculamos la matriz de correlación
matriz_corr = df_final[cols_numericas].corr()

# Definimos el orden deseado de las variables (basado en la Imagen 1), excluyendo Climate
orden_variables = [
    'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
    'Net migration', 'Infant mortality (per 1000 births)', 'GDP ($ per capita)', 'Literacy (%)',
    'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Birthrate',
    'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDP totalpais', 'GDP (%)', 'Value',
    'Total', 'Solid Fuel', 'Liquid Fuel', 'Gas Fuel', 'Cement', 'Gas Flaring', 'Per Capita',
    'Bunker fuels (Not in Total)'
]

# Filtramos para incluir solo las variables disponibles en nuestro dataset
variables_disponibles = [v for v in orden_variables if v in matriz_corr.columns]

# Reordenamos la matriz de correlación
matriz_corr_ordenada = matriz_corr.loc[variables_disponibles, variables_disponibles]

# Creamos el mapa de calor mejorado
plt.figure(figsize=(20, 16))

# Configuramos el mapa de calor sin máscara para mostrar todas las correlaciones
heatmap = sns.heatmap(
    matriz_corr_ordenada,
    cmap='RdBu_r',
    vmax=1,
    vmin=-1,
    center=0,
    square=True,
    linewidths=.5,
    cbar_kws={"shrink": .8},
    annot=True,  # Añadimos valores numéricos
    fmt=".2f",   # Formato de dos decimales
    annot_kws={"size": 8}  # Tamaño de los números
)

# Añadimos título y ajustamos etiquetas
plt.title('Mapa de calor de correlaciones entre variables numéricas (2007)', fontsize=20)
plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(fontsize=9)

plt.tight_layout()
plt.show()

# Analizamos específicamente las correlaciones con las variables de emisiones de CO2
columnas_co2 = ['Total', 'Solid Fuel', 'Liquid Fuel', 'Gas Fuel', 'Cement', 'Gas Flaring', 'Per Capita']
# Verificamos cuáles están disponibles
cols_co2_disponibles = [col for col in columnas_co2 if col in matriz_corr_ordenada.columns]

# Para cada tipo de emisión, mostramos las variables más correlacionadas
for col_co2 in cols_co2_disponibles:
    print(f"\nVariables más correlacionadas con {col_co2}:")
    correlaciones = matriz_corr_ordenada[col_co2].drop(cols_co2_disponibles).sort_values(ascending=False)
    print(correlaciones.head(5))  # Mostramos las 5 más correlacionadas
# Out:
# Número de países en el dataset combinado: 63
# Columnas en el dataset final: ['date', 'Country', 'Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)', 'Net migration', 'Infant mortality (per 1000 births)', 'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service', 'GDP totalpais', 'GDP (%)', 'Country Name', 'Country Code', 'Year_x', 'Value', 'year', 'Year_y', 'Total', 'Solid Fuel', 'Liquid Fuel', 'Gas Fuel', 'Cement', 'Gas Flaring', 'Per Capita', 'Bunker fuels (Not in Total)']
# Variables más correlacionadas con Total:
# GDP totalpais                  0.988277
# GDP (%)                        0.988277
# Bunker fuels (Not in Total)    0.898023
# Population                     0.705160
# Area (sq. mi.)                 0.629876
# Name: Total, dtype: float64
#
# Variables más correlacionadas con Solid Fuel:
# ...

# %% [markdown]
# # Interpretación del Mapa de Calor: Relaciones entre Variables y Emisiones de CO2
#
# Analizando el mapa de calor de correlaciones, puedo identificar las variables económicas, demográficas y de desarrollo humano que muestran las relaciones más importantes con las emisiones de CO2, como solicita el enunciado.
#
# ## Variables Económicas y Emisiones de CO2
#
# - **GDP total** muestra una correlación extremadamente fuerte (0.99) con el Total de emisiones de CO2, indicando que el tamaño de la economía es el factor más determinante del volumen total de emisiones.
#
# - **GDP ($ per capita)** tiene una correlación muy alta (0.80) con las emisiones Per Cápita, lo que confirma que el nivel de desarrollo económico está fuertemente vinculado a la intensidad de emisiones por persona.
#
# - El sector **Service** muestra una correlación moderada (0.21) con las emisiones totales, mientras que sectores como la industria no muestran correlaciones tan fuertes como podría esperarse en este conjunto de datos.
#
# ## Variables Demográficas y Emisiones de CO2
#
# - Sorprendentemente, la **Population** no muestra una fuerte correlación con el Total de emisiones en esta matriz (valor cercano a 0.00), lo que sugiere que el tamaño poblacional por sí solo no es un factor determinante de las emisiones totales en este conjunto de datos.
#
# - **Net migration** presenta una correlación considerable (0.59) con las emisiones Per Cápita, sugiriendo que los países con mayor inmigración neta tienden a tener mayores emisiones por persona.
#
# - **Birthrate** muestra una correlación negativa (-0.04) con las emisiones Per Cápita, mientras que los países con mayor **Infant mortality** tienden a tener menores emisiones per cápita (correlación de -0.59).
#
# ## Variables de Desarrollo Humano y Emisiones de CO2
#
# - **Phones (per 1000)**, un indicador de desarrollo tecnológico, presenta correlaciones fuertes tanto con emisiones totales (0.42) como per cápita (0.71), siendo uno de los mejores predictores de la intensidad de emisiones.
#
# - **Literacy (%)** muestra una correlación positiva moderada (0.48) con las emisiones Per Cápita, indicando que los países con mayor alfabetización tienden a tener mayores emisiones por persona.
#
# - La correlación negativa entre **Infant mortality** y emisiones Per Cápita (-0.59) confirma que países con mayor desarrollo humano (menor mortalidad infantil) tienden a tener mayores emisiones por persona.
#
# ## Interpretación General
#
# Este análisis revela una paradoja del desarrollo: los países con economías más grandes y niveles más altos de desarrollo humano (mayor PIB per cápita, mayor alfabetización, menor mortalidad infantil, mayor acceso a tecnología) tienden a tener mayores emisiones de CO2, especialmente en términos per cápita.
#
# El hecho de que el PIB total tenga una correlación casi perfecta con las emisiones totales (0.99) subraya que el crecimiento económico, bajo los modelos actuales de producción y consumo, está intrínsecamente ligado a mayores emisiones de gases de efecto invernadero.
#
# Esta información es crucial para desarrollar políticas efectivas de mitigación del cambio climático que reconozcan estas relaciones fundamentales entre desarrollo económico y emisiones de carbono.
